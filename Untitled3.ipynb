# %%
import pandas as pd
import random
import numpy as np
from datetime import datetime, timedelta
import ast
import math

# %%
df = pd.read_csv("datalake.csv")
df
# Out:
#                      filename  pentahocounter calendar_timestamp  \
# 0  SD2407091530280-800017-SD1               0            30:27.2
#
#    sd1_v0_headerinformation_destinationdeviceid  \
# 0                                            78
#
#    sd1_v0_headerinformation_datalength  yearhcode  yearlcode  monthhcode  \
# 0                                 1328          2          4           0
#
#    monthlcode  dayhcode  ...  sd1_v12_otmr_otmr_vehicleid12_odometer  \
# 0           7         0  ...                                       0
#
#    sd1_v0_ethernetapplication_commondataofsdr_csvsdr1_commondatatraininformation1_speedlimiterinformation_speedlimitactive  \
# 0                                                  0
#
#    sd1_v0_ethernetapplication_commondataofsdr_csvsdr1_commondatatraininformation1_speedlimiterinformation_constantspeedpowering  \
# 0                                                NaN
#
# ...

# %%
for i in df.columns:
    print(f'{i},')
# Out:
# filename,
# pentahocounter,
# calendar_timestamp,
# sd1_v0_headerinformation_destinationdeviceid,
# sd1_v0_headerinformation_datalength,
# yearhcode,
# yearlcode,
# monthhcode,
# monthlcode,
# dayhcode,
# daylcode,
# hourhcode,
# hourlcode,
# minutehcode,
# minutelcode,
# secondhcode,
# secondlcode,
# milisecondhcode,
# milisecondlcode,
# sd1_v0_validinformation1_validinfoofareano8,
# sd1_v0_validinformation1_validinfoofareano7,
# sd1_v0_validinformation1_validinfoofareano6,
# sd1_v0_validinformation1_validinfoofareano5,
# sd1_v0_validinformation1_validinfoofareano4,
# sd1_v0_validinformation1_validinfoofareano3,
# sd1_v0_validinformation1_validinfoofareano2,
# sd1_v0_validinformation1_validinfoofareano1,
# sd1_v0_sdnumber,
# sd1_v0_loginstatus_coupledunitvehicleid12,
# sd1_v0_loginstatus_coupledunitvehicleid1,
# sd1_v0_loginstatus_selfunitvehicleid12,
# sd1_v0_loginstatus_selfunitvehicleid1,
# sd1_v0_couplingstatus_couplingstatus,
# sd1_v0_couplingstatus_selfunitnetworkunitid,
# ...
