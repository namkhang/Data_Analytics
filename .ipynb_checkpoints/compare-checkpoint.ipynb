# %%
import pandas as pd
import random
import numpy as np
from datetime import timedelta

# %%
file = pd.read_csv('needtorun.txt' , sep='\t', header=None)
result = pd.read_csv('result.txt' , sep='\t', header=None)
file
# Out:
#           0
# 0  woe-sd26

# %%
file_pre = file.iloc[0,0]
file_pro = file.iloc[0,0].replace("-" , "_")
# file_pre= 'woe-sd2'
# file_pro = 'woe_sd2'

# %%
pre = pd.read_parquet(f'./PRE/{file_pre}-pre.parq')
pro = pd.read_csv(f'./gw_lner_asr/SD2403040217100-802015_iep{file_pro}_pro.csv')
pro = pro.drop(columns=['year' , 'month' , 'day' , 'calendar_timestamp']) 
#drop partion and column calendar_timestamp because datatime format diffrent berween pro and pre
pre = pre.drop(columns=['calendar_timestamp']) 
#get data from parquet file so it not has column year , month ,day (partiton)

# %%
# pre = pd.read_parquet('53465cab8f10352a-681068f600000000_1070138833_data.0.parq')
# pre
# Out:
#                             filename  pentahocounter  calendar_timestamp  \
# 0      b'SD2405100559170-395002-SD1'               0 2024-05-10 06:59:19
# 1      b'SD2405100559170-395002-SD1'               1 2024-05-10 06:59:19
# 2      b'SD2405100559170-395002-SD1'               2 2024-05-10 06:59:20
# 3      b'SD2405100559170-395002-SD1'               3 2024-05-10 06:59:20
# 4      b'SD2405100559170-395002-SD1'               4 2024-05-10 06:59:20
# ...                              ...             ...                 ...
# 35995  b'SD2405100559170-395002-SD1'           35995 2024-05-10 08:58:49
# 35996  b'SD2405100559170-395002-SD1'           35996 2024-05-10 08:58:50
# 35997  b'SD2405100559170-395002-SD1'           35997 2024-05-10 08:58:50
# 35998  b'SD2405100559170-395002-SD1'           35998 2024-05-10 08:58:50
# 35999  b'SD2405100559170-395002-SD1'           35999 2024-05-10 08:58:50
#
#        sd1_v0_kindoftext_20h  yearhcode  yearlcode  monthhcode  monthlcode  \
# ...

# %%
# file = file.drop(0)
# file
# Out:
#            0
# 1  lner-sd15
# 2  lner-sd16
# 3  lner-sd26

# %%
# file.to_csv("needtorun.txt" , sep="\t" , header = None , index=False)

# %%
pre
# Out:
#                             filename  pentahocounter  \
# 0      b'SD2403040217100-802015-SD2'               0
# 1      b'SD2403040217100-802015-SD2'               1
# 2      b'SD2403040217100-802015-SD2'               2
# 3      b'SD2403040217100-802015-SD2'               3
# 4      b'SD2403040217100-802015-SD2'               4
# ...                              ...             ...
# 35995  b'SD2403040217100-802015-SD2'           35995
# 35996  b'SD2403040217100-802015-SD2'           35996
# 35997  b'SD2403040217100-802015-SD2'           35997
# 35998  b'SD2403040217100-802015-SD2'           35998
# 35999  b'SD2403040217100-802015-SD2'           35999
#
#        sd2_v0_headerinformation_destinationdeviceid  \
# 0                                                78
# 1                                                78
# 2                                                78
# 3                                                78
# 4                                                78
# ...

# %%
pro
# Out:
#                          filename  pentahocounter  \
# 0      SD2403040217100-802015-SD2               0
# 1      SD2403040217100-802015-SD2               1
# 2      SD2403040217100-802015-SD2               2
# 3      SD2403040217100-802015-SD2               3
# 4      SD2403040217100-802015-SD2               4
# ...                           ...             ...
# 35995  SD2403040217100-802015-SD2           35995
# 35996  SD2403040217100-802015-SD2           35996
# 35997  SD2403040217100-802015-SD2           35997
# 35998  SD2403040217100-802015-SD2           35998
# 35999  SD2403040217100-802015-SD2           35999
#
#        sd2_v0_headerinformation_destinationdeviceid  \
# 0                                                78
# 1                                                78
# 2                                                78
# 3                                                78
# 4                                                78
# ...

# %%
def decodeColumnByte(x):
    for i in range (len(x)) :
        if type(x[i]) == bytes :
            x[i] = x[i].decode("utf-8")
    return x
pre = pre.apply(decodeColumnByte)
pre
#because get data from parquet file so these column has been covert from string to bytes
# the fuction help decode it
# Out:
#                          filename  pentahocounter  calendar_timestamp  \
# 0      SD2405100559170-395002-SD1               0 2024-05-10 06:59:19
# 1      SD2405100559170-395002-SD1               1 2024-05-10 06:59:19
# 2      SD2405100559170-395002-SD1               2 2024-05-10 06:59:20
# 3      SD2405100559170-395002-SD1               3 2024-05-10 06:59:20
# 4      SD2405100559170-395002-SD1               4 2024-05-10 06:59:20
# ...                           ...             ...                 ...
# 35995  SD2405100559170-395002-SD1           35995 2024-05-10 08:58:49
# 35996  SD2405100559170-395002-SD1           35996 2024-05-10 08:58:50
# 35997  SD2405100559170-395002-SD1           35997 2024-05-10 08:58:50
# 35998  SD2405100559170-395002-SD1           35998 2024-05-10 08:58:50
# 35999  SD2405100559170-395002-SD1           35999 2024-05-10 08:58:50
#
#        sd1_v0_kindoftext_20h  yearhcode  yearlcode  monthhcode  monthlcode  \
# ...

# %%
def convertStringtoInt(x):  
    for i in range (len(x)) :
        if type(x[i]) == str : 
            x[i] = x[i].replace('?' ,'').replace('#' ,'').replace('\x00\x00\x00\x00\x00\x00' , '').replace('\x00\x00\x00\x00' , '').replace('\x00\x00' , '')
            try:
                x[i] = int(x[i])
            except: 
                continue
    return x
pre = pre.apply(convertStringtoInt)
pre
#some null column in impala will be exported as '?' , '#' , '\x00\x00\' ,... so we need to replace it to blank
#when we export data, some int column  will be exported to string (example original data is 3456 and after exporting it will be '3456??')
# therefore we need to convert it back to original data type on impala (int) before comparing
# Out:
#                          filename  pentahocounter  calendar_timestamp  \
# 0      SD2405100559170-395002-SD1               0 2024-05-10 06:59:19
# 1      SD2405100559170-395002-SD1               1 2024-05-10 06:59:19
# 2      SD2405100559170-395002-SD1               2 2024-05-10 06:59:20
# 3      SD2405100559170-395002-SD1               3 2024-05-10 06:59:20
# 4      SD2405100559170-395002-SD1               4 2024-05-10 06:59:20
# ...                           ...             ...                 ...
# 35995  SD2405100559170-395002-SD1           35995 2024-05-10 08:58:49
# 35996  SD2405100559170-395002-SD1           35996 2024-05-10 08:58:50
# 35997  SD2405100559170-395002-SD1           35997 2024-05-10 08:58:50
# 35998  SD2405100559170-395002-SD1           35998 2024-05-10 08:58:50
# 35999  SD2405100559170-395002-SD1           35999 2024-05-10 08:58:50
#
#        sd1_v0_kindoftext_20h  yearhcode  yearlcode  monthhcode  monthlcode  \
# ...

# %%
pro = pro.apply(convertStringtoInt)
pro
# Out:
#                          filename  pentahocounter  \
# 0      SD2403040217100-802015-SD2               0
# 1      SD2403040217100-802015-SD2               1
# 2      SD2403040217100-802015-SD2               2
# 3      SD2403040217100-802015-SD2               3
# 4      SD2403040217100-802015-SD2               4
# ...                           ...             ...
# 35995  SD2403040217100-802015-SD2           35995
# 35996  SD2403040217100-802015-SD2           35996
# 35997  SD2403040217100-802015-SD2           35997
# 35998  SD2403040217100-802015-SD2           35998
# 35999  SD2403040217100-802015-SD2           35999
#
#        sd2_v0_headerinformation_destinationdeviceid  \
# 0                                                78
# 1                                                78
# 2                                                78
# 3                                                78
# 4                                                78
# ...

# %%
pre = pre.round(2)
pro = pro.round(2)
# Because rounded values are different between both environments, I need to round them into pro enviroment

# %%
pre
# Out:
#                          filename  pentahocounter  \
# 0      SD2403040217100-802015-SD2               0
# 1      SD2403040217100-802015-SD2               1
# 2      SD2403040217100-802015-SD2               2
# 3      SD2403040217100-802015-SD2               3
# 4      SD2403040217100-802015-SD2               4
# ...                           ...             ...
# 35995  SD2403040217100-802015-SD2           35995
# 35996  SD2403040217100-802015-SD2           35996
# 35997  SD2403040217100-802015-SD2           35997
# 35998  SD2403040217100-802015-SD2           35998
# 35999  SD2403040217100-802015-SD2           35999
#
#        sd2_v0_headerinformation_destinationdeviceid  \
# 0                                                78
# 1                                                78
# 2                                                78
# 3                                                78
# 4                                                78
# ...

# %%
pre = pd.read_csv("dataparsing.csv")
pro = pd.read_csv("dataecoa.csv")
# Out:
# C:\Users\khangnguyen1\AppData\Local\Temp\ipykernel_18108\3560144288.py:1: DtypeWarning: Columns (73,110,874) have mixed types. Specify dtype option on import or set low_memory=False.
#   pre = pd.read_csv("dataparsing.csv")

# %%
pro = pro.drop_duplicates()
pro = pro.drop(columns = ['year' , 'month', 'day'])
pro
# Out:
#                          filename  pentahocounter  \
# 0      SD2304210909530-803003-SD1               0
# 1      SD2304210909530-803003-SD1               1
# 2      SD2304210909530-803003-SD1               2
# 3      SD2304210909530-803003-SD1               3
# 4      SD2304210909530-803003-SD1               4
# ...                           ...             ...
# 69487  SD2304210909530-803003-SD1           35995
# 69488  SD2304210909530-803003-SD1           35996
# 69489  SD2304210909530-803003-SD1           35997
# 69490  SD2304210909530-803003-SD1           35998
# 69491  SD2304210909530-803003-SD1           35999
#
#                   calendar_timestamp  \
# 0      2023/04/21 10:09:51.800000000
# 1      2023/04/21 10:09:52.000000000
# 2      2023/04/21 10:09:52.200000000
# 3      2023/04/21 10:09:52.400000000
# 4      2023/04/21 10:09:52.600000000
# ...                              ...
# 69487  2023/04/21 12:09:20.600000000
# 69488  2023/04/21 12:09:20.800000000
# ...

# %%
pre = pre.drop(columns = needrop)
pre
# Out:
#                          filename  pentahocounter  \
# 0      SD2304210909530-803003-SD1         18765.0
# 1      SD2304210909530-803003-SD1         18766.0
# 2      SD2304210909530-803003-SD1         18767.0
# 3      SD2304210909530-803003-SD1         18768.0
# 4      SD2304210909530-803003-SD1         18769.0
# ...                           ...             ...
# 35996  SD2304210909530-803003-SD1          6241.0
# 35997  SD2304210909530-803003-SD1          6242.0
# 35998  SD2304210909530-803003-SD1          6243.0
# 35999  SD2304210909530-803003-SD1          6244.0
# 36000  SD2304210909530-803003-SD1          6245.0
#
#                   calendar_timestamp  \
# 0      2023/04/21 17:12:08.800000000
# 1      2023/04/21 17:12:09.000000000
# 2      2023/04/21 17:12:09.200000000
# 3      2023/04/21 17:12:09.400000000
# 4      2023/04/21 17:12:09.600000000
# ...                              ...
# 35996  2023/04/21 16:30:34.600000000
# 35997  2023/04/21 16:30:34.800000000
# ...

# %%
pre = pre.drop_duplicates()
pre
# Out:
#                          filename  pentahocounter  \
# 0      SD2304210909530-803003-SD1         18765.0
# 1      SD2304210909530-803003-SD1         18766.0
# 2      SD2304210909530-803003-SD1         18767.0
# 3      SD2304210909530-803003-SD1         18768.0
# 4      SD2304210909530-803003-SD1         18769.0
# ...                           ...             ...
# 35996  SD2304210909530-803003-SD1          6241.0
# 35997  SD2304210909530-803003-SD1          6242.0
# 35998  SD2304210909530-803003-SD1          6243.0
# 35999  SD2304210909530-803003-SD1          6244.0
# 36000  SD2304210909530-803003-SD1          6245.0
#
#                   calendar_timestamp  \
# 0      2023/04/21 17:12:08.800000000
# 1      2023/04/21 17:12:09.000000000
# 2      2023/04/21 17:12:09.200000000
# 3      2023/04/21 17:12:09.400000000
# 4      2023/04/21 17:12:09.600000000
# ...                              ...
# 35996  2023/04/21 16:30:34.600000000
# 35997  2023/04/21 16:30:34.800000000
# ...

# %%
pre = pre.sort_values(by=['pentahocounter'])
# order data by pentahocounter column

# %%
pro = pro.sort_values(by=['pentahocounter'])

# %%
combine = pd.concat([pre, pro])
# combine data both enviroment

# %%
combine
# Out:
#                          filename  pentahocounter  \
# 12432  SD2304210909530-803003-SD1             0.0
# 12433  SD2304210909530-803003-SD1             1.0
# 12434  SD2304210909530-803003-SD1             2.0
# 12435  SD2304210909530-803003-SD1             3.0
# 12436  SD2304210909530-803003-SD1             4.0
# ...                           ...             ...
# 69487  SD2304210909530-803003-SD1         35995.0
# 69488  SD2304210909530-803003-SD1         35996.0
# 69489  SD2304210909530-803003-SD1         35997.0
# 69490  SD2304210909530-803003-SD1         35998.0
# 69491  SD2304210909530-803003-SD1         35999.0
#
#                   calendar_timestamp  \
# 12432  2023/04/21 16:09:51.800000000
# 12433  2023/04/21 16:09:52.000000000
# 12434  2023/04/21 16:09:52.200000000
# 12435  2023/04/21 16:09:52.400000000
# 12436  2023/04/21 16:09:52.600000000
# ...                              ...
# 69487  2023/04/21 12:09:20.600000000
# 69488  2023/04/21 12:09:20.800000000
# ...

# %%
combine = combine.drop_duplicates()
combine
# If when drop duplicate the number of rows is equal to the number of rows of each environment, 
#that means the data of the two environments is the same
# Out:
#                          filename  pentahocounter  \
# 12432  SD2304210909530-803003-SD1             0.0
# 12433  SD2304210909530-803003-SD1             1.0
# 12434  SD2304210909530-803003-SD1             2.0
# 12435  SD2304210909530-803003-SD1             3.0
# 12436  SD2304210909530-803003-SD1             4.0
# ...                           ...             ...
# 69487  SD2304210909530-803003-SD1         35995.0
# 69488  SD2304210909530-803003-SD1         35996.0
# 69489  SD2304210909530-803003-SD1         35997.0
# 69490  SD2304210909530-803003-SD1         35998.0
# 69491  SD2304210909530-803003-SD1         35999.0
#
#                   calendar_timestamp  \
# 12432  2023/04/21 16:09:51.800000000
# 12433  2023/04/21 16:09:52.000000000
# 12434  2023/04/21 16:09:52.200000000
# 12435  2023/04/21 16:09:52.400000000
# 12436  2023/04/21 16:09:52.600000000
# ...                              ...
# 69487  2023/04/21 12:09:20.600000000
# 69488  2023/04/21 12:09:20.800000000
# ...

# %%
if len(combine) == len(pro) :
        result=pd.concat([result, pd.DataFrame([f'{file-pre}-success'] , columns = [0])] , ignore_index = True)
result.to_csv("result.txt" , sep="\t" , header = None , index=False)

# %%
# pd.DataFrame([f'hello-success'] , columns = [0])
# Out:
#                0
# 0  hello-success

# %%
list_different = []  
for i in range(len(pre)): 
   if(list(pre.iloc[i,:]) != list(pro.iloc[i,:])):
        list_different.append(list(pre.iloc[i,:]))

# %%
df_result = pd.DataFrame(list_different , columns = pre.columns)
df_result
# Out:
#                          filename  pentahocounter       calendar_timestamp  \
# 0      SD2304210909530-803003-SD1               0  2023-04-21 16:09:51.800
# 1      SD2304210909530-803003-SD1               1  2023-04-21 16:09:52.000
# 2      SD2304210909530-803003-SD1               2  2023-04-21 16:09:52.200
# 3      SD2304210909530-803003-SD1               3  2023-04-21 16:09:52.400
# 4      SD2304210909530-803003-SD1               4  2023-04-21 16:09:52.600
# ...                           ...             ...                      ...
# 35995  SD2304210909530-803003-SD1           35995  2023-04-21 18:09:20.600
# 35996  SD2304210909530-803003-SD1           35996  2023-04-21 18:09:20.800
# 35997  SD2304210909530-803003-SD1           35997  2023-04-21 18:09:21.000
# 35998  SD2304210909530-803003-SD1           35998  2023-04-21 18:09:21.200
# 35999  SD2304210909530-803003-SD1           35999  2023-04-21 18:09:21.400
#
#        sd1_v0_headerinformation_destinationdeviceid  \
# ...

# %%
def columnDefferent(colpre , colpro):
    result = []
    for i in range (len(colpre)):
        if(colpre[i] != colpro[i] and str(colpre[i]) != "nan"):
            result.append({'index' : i , 'value' : colpre[i]})
    return result

columnDefferent(list(pre.iloc[35995,:]) , list(pro.iloc[35995,:]))

# the function helps detect which columns contain different values between the two environments
# Out:
# [{'index': 2, 'value': '2023-04-21 18:09:20.600'},
#  {'index': 73, 'value': nan},
#  {'index': 110, 'value': nan},
#  {'index': 116, 'value': '57.120.000.000.000.000'},
#  {'index': 244, 'value': '9.0'},
#  {'index': 830, 'value': nan},
#  {'index': 840, 'value': '57.123.000.000.000.000'},
#  {'index': 1258, 'value': '11.446.882.000.000.000'},
#  {'index': 2081, 'value': '11.407.575.000.000.000'}]

# %%
pre.iloc[35995 , 2081] 
# pre.iloc[19053 , 1304] 
# export value each enviroment
# Out:
# '11.407.575.000.000.000'

# %%
pro.columns[2081]
#show column name
# Out:
# 'sd1_v12_assignment_vehicleifunit_vehicleid12leadingcar_vehicleai_batteryvoltage'

# %%
# pre.loc[4453 , 'sd1_v0_ethernetapplication_commondataofsdr_mlc_sdr1_trainid_trainid'].replace('\x00\x00\x00\x00\x00\x00' , '')

# %%
# list_tmp = list(pre.iloc[19053 , :])

# for index in range (len(list_tmp)) :
#        if '.' in str(list_tmp[index]) :
#             print(index)

# %%
# pre.to_csv('SE.csv' , index = False,escapechar='\\')

# %%
needrop = ['sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_tractioninformation1_tractionofvid6_slowspeedmodesw',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_tractioninformation1_tractionofvid6_tractionwsdpdetection',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_tractioninformation1_tractionofvid6_powerregenerationmode',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_tractioninformation1_tractionofvid6_poweringmode',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_tractioninformation1_tractionofvid6_tractionfault',
       'sd1_v4_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_bcuinformation_brakecylinderpressureofvid4',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_bcuinformation_brakecylinderpressureofvid6',
       'sd1_v8_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_bcuinformation_brakecylinderpressureofvid8',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_tractioninformation3_regenerativebrakefromtractionofv_id6',
       'sd1_v8_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_bcuinformation_snowbrakeactivevid8',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_bcuinformation_snowbrakeactivevid6',
       'sd1_v4_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_bcuinformation_snowbrakeactivevid4',
       'sd1_v4_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_sdodoorreleasepattern_doorofvid4reardoor',
       'sd1_v4_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_sdodoorreleasepattern_doorofvid4frontdoor',
       'sd1_v8_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_sdodoorreleasepattern_doorofvid8reardoor',
       'sd1_v8_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_sdodoorreleasepattern_doorofvid8frontdoor',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_sdodoorreleasepattern_doorofvid6reardoor',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_sdodoorreleasepattern_doorofvid6frontdoor',
       'sd1_v4_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_pauinformation1_pauoperationofvid4_pauoperation',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_pauinformation2_pauoperationofvid6_pauoperation',
       'sd1_v8_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_pauinformation2_pauoperationofvid8_pauoperation',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno1andno2_torquedetectionvaluefromtractionofv_id6',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_tractioninformation1_tractionofvid6_slowspeedmodesw',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_tractioninformation1_tractionofvid6_tractionwsdpdetection',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_tractioninformation1_tractionofvid6_powerregenerationmode',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_tractioninformation1_tractionofvid6_poweringmode',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_tractioninformation1_tractionofvid6_tractionfault',
       'sd1_v4_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_bcuinformation_brakecylinderpressureofvid4',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_bcuinformation_brakecylinderpressureofvid6',
       'sd1_v8_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_bcuinformation_brakecylinderpressureofvid8',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_tractioninformation3_regenerativebrakefromtractionofv_id6',
       'sd1_v8_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_bcuinformation_snowbrakeactivevid8',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_bcuinformation_snowbrakeactivevid6',
       'sd1_v4_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_bcuinformation_snowbrakeactivevid4',
       'sd1_v4_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_sdodoorreleasepattern_doorofvid4reardoor',
       'sd1_v4_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_sdodoorreleasepattern_doorofvid4frontdoor',
       'sd1_v8_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_sdodoorreleasepattern_doorofvid8reardoor',
       'sd1_v8_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_sdodoorreleasepattern_doorofvid8frontdoor',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_sdodoorreleasepattern_doorofvid6reardoor',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_sdodoorreleasepattern_doorofvid6frontdoor',
       'sd1_v4_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_pauinformation1_pauoperationofvid4_pauoperation',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_pauinformation2_pauoperationofvid6_pauoperation',
       'sd1_v8_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_pauinformation2_pauoperationofvid8_pauoperation',
       'sd1_v6_otmr_otmr_mlcsdr1_dataforotmrasno3andno4_traininformation_torquedetectionvaluefromtractionofv_id6',
       'sd1_v4_assignment_carnumberofvehicleid4_carnumber_carnumber',
       'sd1_v6_assignment_carnumberofvehicleid6_carnumber_carnumber',
       'sd1_v8_assignment_carnumberofvehicleid8_carnumber_carnumber',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_healthstatusofcu',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_healthstatusofdnra',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_airsuspensionpressuredown',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_brakecockisolated',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_parkingbrake',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_brakedragging',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_bcps',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_mcbstatusforbatterycharger2',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_mcbstatusforbatterycharger1',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_faultofaps',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_mcbstatusforcomfort2',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_mcbstatusfordegradedmode2',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_mcbstatusforsafetysystem2',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_mcbstatusforoperatingequipment2',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_mcbstatusforhvac',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_faultofhvac',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_guardpanelinvestibuleright',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_guardpanelinvestibuleleft',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_mcbstatusformtbmn',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_mcbstatusfortms2',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_mcbstatusforpassengersystem2',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_mcbstatusforbkk',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_bkkstatus',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_vcbnstatus',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_acocrstatus',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_svtrstatus',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_faultofbatterybackupunitforreservelamp3',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_faultofbatterybackupunitforreservelamp2',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_faultofbatterybackupunitforreservelamp1',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_systemfaultforcatering',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_mcbfaultforcatering',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_plcpoweron',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_lowwaterlevel',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_freshwateruvsystemfault',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_freshwateruvsystemmaintenance',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_batteryon',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_mcbstatusinbatterybox',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_mcbstatusforcatering',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_hotaxlebearingdetection8',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_hotaxlebearingdetection7',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_hotaxlebearingdetection6',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_hotaxlebearingdetection5',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_hotaxlebearingdetection4',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_hotaxlebearingdetection3',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_hotaxlebearingdetection2',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_hotaxlebearingdetection1',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_maintransformerareafault',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_maintransformerareafire',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_utilitytoiletareafault',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_utilitytoiletareafire',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_saloonvestibuleareafault',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_saloonvestibuleareafire',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_powersupplyforgangwaydoor',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_mcbstatusfortoilet',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_powersupplyfortoiletsystem',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_toiletoutofservice2',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_toiletoutofservice1',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle24vdi_faultofsrdcu',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle110vdi_vcb3',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle110vdi_powersupplyforpassengercountingsystem',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle110vdi_powersupplyforpasystem',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle110vdi_powersupplyforsrdcontrolunit',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle110vdi_powersupplyforpisdisplay',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle110vdi_powersupplyforhabdcircuit',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle110vdi_powersupplyforhvac',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle110vdi_powersupplyforaps',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle110vdi_powersupplyforbrake',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicle110vdi_accocr3reset',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_invdoorenable4',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_invdoorenable3',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_invdoorenable2',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_invdoorenable1',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_doorenable4',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_doorenable3',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_doorenable2',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_doorenable1',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_errordetectionofdi00d3',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_errordetectionofdi00d2',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_errordetectionofdi00d1',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_errordetectionofdi00d0',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_errordetectionofdi01d3',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_errordetectionofdi01d2',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_errordetectionofdi01d1',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_errordetectionofdi01d0',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_invd3',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_invsaloonlightingdimup',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_invbkk',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_invsaloonlightingdegrading',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_saloonlightingdimup',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_bkk',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_saloonlightingdegrading',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_errordetectionofdi04d3',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_errordetectionofdi04d2',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_errordetectionofdi04d1',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_errordetectionofdi04d0',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_errordetectionofdi05d3',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_errordetectionofdi05d2',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_errordetectionofdi05d1',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehiclefvdo_errordetectionofdi05d0',
       'sd1_v4_assignment_vehicleifunit_vehicleid4tcar_vehicleai_batteryvoltage',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_healthstatusofcu',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_healthstatusofdnra',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_airsuspensionpressuredown',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_brakecockisolated',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_brakedragging',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_bcps',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_mcbstatusforcomfort2',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_mcbstatusfordegradedmode2',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_mcbstatusforsafetysystem2',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_mcbstatusforoperatingequipment2',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_mcbstatusforhvac',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_faultofhvac',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_guardpanelinvestibuleright',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_guardpanelinvestibuleleft',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_mcbstatusforcilineinputsyn',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_mcbstatusforcicontrolvoltagecicn',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_mcbstatusforcibloweraccn',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_tractioncutout',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_mcbstatusfortms2',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_mcbstatusforpassengersystem2',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_tocserverfault',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_powersupplyfortocserver',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_mcbstatusforbkk',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_bkkstatus',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_fuellevel5',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_fuellevel4',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_fuellevel3',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_fuellevel2',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_fuellevel1',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_faultofbatterybackupunitforreservelamp3',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_faultofbatterybackupunitforreservelamp2',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_faultofbatterybackupunitforreservelamp1',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_systemfaultforcatering',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_mcbfaultforcatering',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_plcpoweron',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_lowwaterlevel',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_freshwateruvsystemfault',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_freshwateruvsystemmaintenance',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_mcbstatusforcatering',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_hotaxlebearingdetection8',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_hotaxlebearingdetection7',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_hotaxlebearingdetection6',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_hotaxlebearingdetection5',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_hotaxlebearingdetection4',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_hotaxlebearingdetection3',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_hotaxlebearingdetection2',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_hotaxlebearingdetection1',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_utilityareafault',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_utilityareafire',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_saloonvestibuleareafault',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_saloonvestibuleareafire',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_powersupplyforgangwaydoor',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_generatorunitarefault',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_generatorunitareafire',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_tractionareafault',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_tractionareafire',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_mcbstatusfortoilet',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_powersupplyfortoiletsystem',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_toiletoutofservice2',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_toiletoutofservice1',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle24vdi_faultofsrdcu',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle110vdi_powersupplyfortraction',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle110vdi_powersupplyforpassengercountingsystem',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle110vdi_powersupplyforpasystem',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle110vdi_powersupplyforsrdcontrolunit',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle110vdi_powersupplyforpisdisplay',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle110vdi_powersupplyforhabdcircuit',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle110vdi_powersupplyforhvac',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle110vdi_emergencyenginestopbuttonbodyside',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle110vdi_powersupplyforbrake',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehicle110vdi_powersupplyforobs',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_invdoorenable4',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_invdoorenable3',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_invdoorenable2',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_invdoorenable1',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_doorenable4',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_doorenable3',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_doorenable2',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_doorenable1',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_errordetectionofdi00d3',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_errordetectionofdi00d2',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_errordetectionofdi00d1',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_errordetectionofdi00d0',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_errordetectionofdi01d3',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_errordetectionofdi01d2',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_errordetectionofdi01d1',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_errordetectionofdi01d0',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_invd3',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_invsaloonlightingdimup',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_invbkk',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_invsaloonlightingdegrading',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_saloonlightingdimup',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_bkk',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_saloonlightingdegrading',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_errordetectionofdi04d3',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_errordetectionofdi04d2',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_errordetectionofdi04d1',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_errordetectionofdi04d0',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_errordetectionofdi05d3',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_errordetectionofdi05d2',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_errordetectionofdi05d1',
       'sd1_v6_assignment_vehicleifunit_vehicleid6mcar_vehiclefsdo_errordetectionofdi05d0',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_healthstatusofcu',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_healthstatusofdnra',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_airsuspensionpressuredown',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_brakecockisolated',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_parkingbrake',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_brakedragging',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_bcps',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_mcbstatusforbatterycharger2',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_mcbstatusforbatterycharger1',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_faultofaps',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_mcbstatusforcomfort2',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_mcbstatusfordegradedmode2',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_mcbstatusforsafetysystem2',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_mcbstatusforoperatingequipment2',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_mcbstatusforhvac',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_faultofhvac',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_guardpanelinvestibuleright',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_guardpanelinvestibuleleft',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_mcbstatusformtbmn',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_mcbstatusfortms2',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_mcbstatusforpassengersystem2',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_mcbstatusforbkk',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_bkkstatus',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_vcbnstatus',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_acocrstatus',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_svtrstatus',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_faultofbatterybackupunitforreservelamp3',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_faultofbatterybackupunitforreservelamp2',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_faultofbatterybackupunitforreservelamp1',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_systemfaultforcatering',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_mcbfaultforcatering',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_plcpoweron',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_lowwaterlevel',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_freshwateruvsystemfault',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_freshwateruvsystemmaintenance',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_batteryon',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_mcbstatusinbatterybox',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_mcbstatusforcatering',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_hotaxlebearingdetection8',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_hotaxlebearingdetection7',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_hotaxlebearingdetection6',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_hotaxlebearingdetection5',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_hotaxlebearingdetection4',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_hotaxlebearingdetection3',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_hotaxlebearingdetection2',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_hotaxlebearingdetection1',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_maintransformerareafault',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_maintransformerareafire',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_utilitytoiletareafault',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_utilitytoiletareafire',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_saloonvestibuleareafault',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_saloonvestibuleareafire',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_powersupplyforgangwaydoor',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_mcbstatusfortoilet',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_powersupplyfortoiletsystem',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_toiletoutofservice2',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_toiletoutofservice1',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle24vdi_faultofsrdcu',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle110vdi_vcb3',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle110vdi_powersupplyforpassengercountingsystem',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle110vdi_powersupplyforpasystem',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle110vdi_powersupplyforsrdcontrolunit',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle110vdi_powersupplyforpisdisplay',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle110vdi_powersupplyforhabdcircuit',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle110vdi_powersupplyforhvac',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle110vdi_powersupplyforaps',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle110vdi_powersupplyforbrake',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicle110vdi_accocr3reset',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_invdoorenable4',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_invdoorenable3',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_invdoorenable2',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_invdoorenable1',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_doorenable4',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_doorenable3',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_doorenable2',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_doorenable1',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_errordetectionofdi00d3',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_errordetectionofdi00d2',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_errordetectionofdi00d1',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_errordetectionofdi00d0',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_errordetectionofdi01d3',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_errordetectionofdi01d2',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_errordetectionofdi01d1',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_errordetectionofdi01d0',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_invd3',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_invsaloonlightingdimup',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_invbkk',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_invsaloonlightingdegrading',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_saloonlightingdimup',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_bkk',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_saloonlightingdegrading',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_errordetectionofdi04d3',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_errordetectionofdi04d2',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_errordetectionofdi04d1',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_errordetectionofdi04d0',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_errordetectionofdi05d3',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_errordetectionofdi05d2',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_errordetectionofdi05d1',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehiclefvdo_errordetectionofdi05d0',
       'sd1_v8_assignment_vehicleifunit_vehicleid8tcar_vehicleai_batteryvoltage',
        'sd1_v1_otmr_otmr_vehicleid1_odometer',
        'sd1_v12_otmr_otmr_vehicleid12_odometer'
]

# %%
len(needrop)
# Out:
# 351

# %%
for i in pro.columns :
    if i not in pre.columns :
        print(i)
# Out:
# derived_speed_mph
# derived_distance_miles

# %%
pre["sd1_v12_assignment_vehicleifunit_vehicleid12leadingcar_vehicleai_batteryvoltage"]
# Out:
# 0        11.315.289.000.000.000
# 1        11.316.998.000.000.000
# 2        11.316.998.000.000.000
# 3                     1.131.358
# 4        11.316.998.000.000.000
#                   ...
# 35995    11.407.575.000.000.000
# 35996                11.400.739
# 35997                11.392.194
# 35998    11.385.358.000.000.000
# 35999    11.376.813.000.000.000
# Name: sd1_v12_assignment_vehicleifunit_vehicleid12leadingcar_vehicleai_batteryvoltage, Length: 36000, dtype: object

# %%
pro["sd1_v12_assignment_vehicleifunit_vehicleid12leadingcar_vehicleai_batteryvoltage"]
# Out:
# 0        113.15289
# 1        113.16998
# 2        113.16998
# 3        113.13580
# 4        113.16998
#            ...
# 69487    114.07575
# 69488    114.00739
# 69489    113.92194
# 69490    113.85358
# 69491    113.76813
# Name: sd1_v12_assignment_vehicleifunit_vehicleid12leadingcar_vehicleai_batteryvoltage, Length: 36000, dtype: float64

# %%
pre
# Out:
#                          filename  pentahocounter  \
# 0      SD2304210909530-803003-SD1         12508.0
# 1      SD2304210909530-803003-SD1         12509.0
# 2      SD2304210909530-803003-SD1         12510.0
# 3      SD2304210909530-803003-SD1         12511.0
# 4      SD2304210909530-803003-SD1         12512.0
# ...                           ...             ...
# 35996  SD2304210909530-803003-SD1          6241.0
# 35997  SD2304210909530-803003-SD1          6242.0
# 35998  SD2304210909530-803003-SD1          6243.0
# 35999  SD2304210909530-803003-SD1          6244.0
# 36000  SD2304210909530-803003-SD1          6245.0
#
#                   calendar_timestamp  \
# 0      2023/04/21 16:51:22.800000000
# 1      2023/04/21 16:51:23.000000000
# 2      2023/04/21 16:51:23.200000000
# 3      2023/04/21 16:51:23.400000000
# 4      2023/04/21 16:51:23.600000000
# ...                              ...
# 35996  2023/04/21 16:30:34.600000000
# 35997  2023/04/21 16:30:34.800000000
# ...

# %%
pre = pre.drop(columns = ['Year' , 'Month', 'Day'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 pre = pre.drop(columns = ['Year' , 'Month', 'Day'])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
# ...

# %%
pre
# Out:
#                          filename  pentahocounter  \
# 0      SD2304210909530-803003-SD1         12508.0
# 1      SD2304210909530-803003-SD1         12509.0
# 2      SD2304210909530-803003-SD1         12510.0
# 3      SD2304210909530-803003-SD1         12511.0
# 4      SD2304210909530-803003-SD1         12512.0
# ...                           ...             ...
# 35996  SD2304210909530-803003-SD1          6241.0
# 35997  SD2304210909530-803003-SD1          6242.0
# 35998  SD2304210909530-803003-SD1          6243.0
# 35999  SD2304210909530-803003-SD1          6244.0
# 36000  SD2304210909530-803003-SD1          6245.0
#
#                   calendar_timestamp  \
# 0      2023/04/21 16:51:22.800000000
# 1      2023/04/21 16:51:23.000000000
# 2      2023/04/21 16:51:23.200000000
# 3      2023/04/21 16:51:23.400000000
# 4      2023/04/21 16:51:23.600000000
# ...                              ...
# 35996  2023/04/21 16:30:34.600000000
# 35997  2023/04/21 16:30:34.800000000
# ...

# %%
pro
# Out:
#                          filename  pentahocounter  \
# 0      SD2304210909530-803003-SD1               0
# 1      SD2304210909530-803003-SD1               1
# 2      SD2304210909530-803003-SD1               2
# 3      SD2304210909530-803003-SD1               3
# 4      SD2304210909530-803003-SD1               4
# ...                           ...             ...
# 69487  SD2304210909530-803003-SD1           35995
# 69488  SD2304210909530-803003-SD1           35996
# 69489  SD2304210909530-803003-SD1           35997
# 69490  SD2304210909530-803003-SD1           35998
# 69491  SD2304210909530-803003-SD1           35999
#
#                   calendar_timestamp  \
# 0      2023/04/21 10:09:51.800000000
# 1      2023/04/21 10:09:52.000000000
# 2      2023/04/21 10:09:52.200000000
# 3      2023/04/21 10:09:52.400000000
# 4      2023/04/21 10:09:52.600000000
# ...                              ...
# 69487  2023/04/21 12:09:20.600000000
# 69488  2023/04/21 12:09:20.800000000
# ...

# %%
pro.head(1)
# Out:
#                      filename  pentahocounter             calendar_timestamp  \
# 0  SD2304210909530-803003-SD1               0  2023/04/21 10:09:51.800000000
#
#    sd1_v0_headerinformation_destinationdeviceid  \
# 0                                            78
#
#    sd1_v0_headerinformation_datalength  YearHCode  YearLCode  MonthHCode  \
# 0                                 1328          2          3           0
#
#    MonthLCode  DayHCode  ...  \
# 0           4         2  ...
#
#    sd1_v12_assignment_vehicleifunit_vehicleid12leadingcar_vehiclefvdo_errordetectionofdi05d0  \
# 0                                                  0
#
#    sd1_v12_assignment_vehicleifunit_vehicleid12leadingcar_vehicleai_batteryvoltage  \
# 0                                          113.15289
#
#    derived_speed_mph  derived_distance_miles  \
# 0                0.0                578190.0
#
# ...

# %%
pre.head(1)
# Out:
#                          filename  pentahocounter  \
# 12432  SD2304210909530-803003-SD1             0.0
#
#                   calendar_timestamp  \
# 12432  2023/04/21 16:09:51.800000000
#
#        sd1_v0_headerinformation_destinationdeviceid  \
# 12432                                          78.0
#
#        sd1_v0_headerinformation_datalength  YearHCode  YearLCode  MonthHCode  \
# 12432                               1328.0        2.0        3.0         0.0
#
#        MonthLCode  DayHCode  ...  \
# 12432         4.0       2.0  ...
#
#        sd1_v12_assignment_vehicleifunit_vehicleid12leadingcar_vehiclefvdo_errordetectionofdi05d0  \
# 12432                                                0.0
#
#        sd1_v12_assignment_vehicleifunit_vehicleid12leadingcar_vehicleai_batteryvoltage  \
# 12432                                                NaN
#
#        derived_speed_mph  derived_distance_miles  \
# 12432                0.0                578190.0
#
# ...

# %%
# Out:
# False
