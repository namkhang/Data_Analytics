# %%
import pandas as pd
import random
import numpy as np

# %%
df = pd.read_csv('investigate.csv')
df1 = pd.read_csv('investigate-1.csv')

# %%
df1
# Out:
#       Folder Name                VM                     Source
# 0        20180120  hcp-data-test-06  /data_sync/IEPGW/20180120
# 1        20180122  hcp-data-test-06  /data_sync/IEPGW/20180122
# 2        20180123  hcp-data-test-06  /data_sync/IEPGW/20180123
# 3        20180124  hcp-data-test-06  /data_sync/IEPGW/20180124
# 4        20180125  hcp-data-test-06  /data_sync/IEPGW/20180125
# ...           ...               ...                        ...
# 1832     20230426  hcp-data-test-09  /data_sync/IEPGW/20230426
# 1833     20230427  hcp-data-test-09  /data_sync/IEPGW/20230427
# 1834     20230428  hcp-data-test-09  /data_sync/IEPGW/20230428
# 1835     20230429  hcp-data-test-09  /data_sync/IEPGW/20230429
# 1836     20230430  hcp-data-test-09  /data_sync/IEPGW/20230430
#
# [1837 rows x 3 columns]

# %%
df.merge(df1 ,how = 'left' , on =['Folder Name']).to_csv('result-investigate.csv',index = False)

# %%
df3 = pd.read_csv('investigate-3.csv')

# %%
df3['fullpath'] = df3.apply(lambda x : f'backup_tgz/IEPTPE/{x[0]}/{x[1]}' , axis = 1 )
df3
# Out:
# C:\Users\khangnguyen1\AppData\Local\Temp\ipykernel_9260\1919861612.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df3['fullpath'] = df3.apply(lambda x : f'backup_tgz/IEPTPE/{x[0]}/{x[1]}' , axis = 1 )
#       Folder                IT1_filename  \
# 0   20191008  SD1907251925511-802207.tgz
# 1   20191008  SD1907252034150-802207.tgz
# 2   20191008  SD1907260033310-802207.tgz
# 3   20191008  SD1907260233080-802207.tgz
# 4   20191008  SD1907260432461-802207.tgz
# 5   20191008  SD1907260632230-802207.tgz
# 6   20191008  SD1907261231150-802207.tgz
# 7   20191008  SD1907270028580-802207.tgz
# 8   20191008  SD1907301437591-802207.tgz
# 9   20191008  SD1907302049550-802207.tgz
# 10  20191008  SD1907310049090-802207.tgz
# 11  20191008  SD1907310448231-802207.tgz
# ...

# %%
df3.to_csv("result-investigate-3.csv" , index = False)
