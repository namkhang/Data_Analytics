# %%
import pandas as pd
import random
import numpy as np
from datetime import timedelta

# %%
needtodownload = pd.read_csv("needtodownload.csv")
needtodownload
# Out:
#                                                 Signal
# 0                                            YearHCode
# 1                                            YearLCode
# 2                                           MonthHCode
# 3                                           MonthLCode
# 4                                             DayHCode
# ..                                                 ...
# 287  sd1_v0_ethernetapplication_commondataofsdr_mlc...
# 288  sd1_v0_ethernetapplication_commondataofsdr_mlc...
# 289  sd1_v0_ethernetapplication_commondataofsdr_mlc...
# 290                           sd1_v0_trainuid_trainuid
# 291  sd1_v0_ethernetapplication_commondataofsdr_mlc...
#
# [292 rows x 1 columns]

# %%
arrray_rs = list(needtodownload["Signal"].values)
arrray_rs
# Out:
# ['YearHCode',
#  'YearLCode',
#  'MonthHCode',
#  'MonthLCode',
#  'DayHCode',
#  'DayLCode',
#  'HourHCode',
#  'HourLCode',
#  'MinuteHCode',
#  'MinuteLCode',
#  'SecondHCode',
#  'SecondLCode',
#  'MilisecondHCode',
#  'MilisecondLCode',
#  'sd1_v0_couplingstatus_couplingstatus',
#  'derived_distance_miles',
#  'derived_speed_mph',
#  'sd1_v0_otmr_otmr_mlcsdr1_commondataforotmr_trainspeedfrometcs_trainspeedfrometcs',
#  'sd1_v0_assignment_odometer',
#  'sd7_v0_pcs_pcs_sd_wholetraininformation1_currenttrainpassengeroccupancy',
#  'sd3_v0_traction_tractioncontrol_csvsdr1_loadweightinformation_numberofhealthytraction',
#  'sd3_v0_traction_tractioncontrol_csvsdr1_loadweightinformation_loadweightofcartractionofasno1',
#  'sd3_v0_traction_tractioncontrol_csvsdr1_loadweightinformation_loadweightofcartractionofasno2',
#  'sd3_v0_traction_tractioncontrol_csvsdr1_loadweightinformation_loadweightofcartractionofasno3',
# ...

# %%
common = list(needtodownload["Signal"].values[0 : 14])
common
# Out:
# ['YearHCode',
#  'YearLCode',
#  'MonthHCode',
#  'MonthLCode',
#  'DayHCode',
#  'DayLCode',
#  'HourHCode',
#  'HourLCode',
#  'MinuteHCode',
#  'MinuteLCode',
#  'SecondHCode',
#  'SecondLCode',
#  'MilisecondHCode',
#  'MilisecondLCode']

# %%
','.join((common + [i for i in arrray_rs if "sd26" in i]))
# Out:
# 'YearHCode,YearLCode,MonthHCode,MonthLCode,DayHCode,DayLCode,HourHCode,HourLCode,MinuteHCode,MinuteLCode,SecondHCode,SecondLCode,MilisecondHCode,MilisecondLCode,sd26_v1_ridecomfortmonitoring_ridecomfortmonitoring_vehicleid1_sdr_traininformation1_loadweightonvehicle,sd26_v2_ridecomfortmonitoring_ridecomfortmonitoring_vehicleid2_sdr_traininformation1_loadweightonvehicle,sd26_v12_ridecomfortmonitoring_ridecomfortmonitoring_vehicleid12_sdr_traininformation1_loadweightonvehicle'

# %%
[i for i in arrray_rs if "sd1" in i]
# Out:
# ['sd1_v0_couplingstatus_couplingstatus',
#  'sd1_v0_otmr_otmr_mlcsdr1_commondataforotmr_trainspeedfrometcs_trainspeedfrometcs',
#  'sd1_v0_assignment_odometer',
#  'sd1_v1_assignment_cabifunit_vehicleid1_cab24vddi_pantographstatus',
#  'sd1_v12_assignment_cabifunit_vehicleid12_cab24vddi_pantographstatus',
#  'sd1_v12_assignment_cabifunit_vehicleid12_cab24vdi_pantographautodropdetection',
#  'sd1_v1_assignment_cabifunit_vehicleid1_cab24vdi_pantographautodropdetection',
#  'sd1_v0_ethernetapplication_commondataofsdr_csvsdr1_commondatatraininformation1_sleepmode',
#  'sd1_v0_loginstatus_selfunitvehicleid1',
#  'sd1_v0_loginstatus_coupledunitvehicleid12',
#  'sd1_v0_ethernetapplication_commondataofsdr_mlcsdr1_commondatatrainid',
#  'sd1_v0_ethernetapplication_commondataofsdr_mlcsdr1_commondatagpsinformation_directionoflatitude',
#  'sd1_v0_ethernetapplication_commondataofsdr_mlcsdr1_commondatagpsinformation_latitudedegrees',
# ...
